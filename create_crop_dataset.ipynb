# %%
import numpy as np
import cv2 as cv

# %%
face_cascade = cv.CascadeClassifier('data/haarcascade_frontalface_default.xml')

# %%
import os
import sys

# %%
imgs = []

# %%
path = '../../perso_project/downloads/'
for dir_name in os.listdir(path):
    for file in os.listdir(path + dir_name):
        imgs.append("{}{}/{}".format(path, dir_name, file))

# %%
print (len(imgs))
# Out:
# 9924

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
print (imgs[0])
# Out:
# ../../perso_project/downloads/Yara Greyjoy games of thrones/Yara Greyjoy 49. s-l300.jpg

# %%
imgs[0].split(os.path.sep)[-1]
# Out:
# 'Yara Greyjoy 49. s-l300.jpg'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# img=mpimg.imread(img)
imgplot = plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-358eabbaaf6b> in <module>
#       2 import matplotlib.image as mpimg
#       3 # img=mpimg.imread(img)
# ----> 4 imgplot = plt.imshow(img)
#       5 plt.show()
#
# NameError: name 'img' is not defined

# %%
for ind, file in enumerate(imgs):
    if ind % 10 == 0:
        print (ind)
    img = cv.imread(file)
    try:
        gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:

            crop_img = img[y-30:y+h+30, x-20:x+w+50]
            cv.imwrite('dataset/{}'.format(file.split(os.path.sep)[-1]),crop_img)
    except:
        print ("Not processed {}".format(file))
# Out:
# 0
# Not processed ../../perso_project/downloads/Yara Greyjoy games of thrones/Yara Greyjoy 96. tumblr_mjzdxxfrwa1qg0lheo2_250.gif
# Not processed ../../perso_project/downloads/Yara Greyjoy games of thrones/Yara Greyjoy 82. tumblr_inline_o6yu4kijd11t8wtzm_500.gif
# 10
# 20
# Not processed ../../perso_project/downloads/Yara Greyjoy games of thrones/Yara Greyjoy 95. drearyhotaustralianfurseal-size_restricted.gif
# 30
# 40
# 50
# 60
# 70
# Not processed ../../perso_project/downloads/Yara Greyjoy games of thrones/Yara Greyjoy 83. giphy.gif
# 80
# 90
# 100
# Not processed ../../perso_project/downloads/Roose Bolton games of thrones/Roose Bolton 91. tumblr_olbms6lpcr1vmesgxo2_500.gif
# 110
# Not processed ../../perso_project/downloads/Roose Bolton games of thrones/Roose Bolton 75. 5krj.gif
# Not processed ../../perso_project/downloads/Roose Bolton games of thrones/Roose Bolton 45. tumblr_n276imej5b1qddfrco1_500.gif
# ...

# %%
cropLst = os.listdir('dataset/')

# %%
cropLst = []

# %%
from glob import glob

for file in glob('dataset/*/*'):
    cropLst.append(file)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import PIL
import numpy as np
import cv2

# %%
cols = 8
rows = 3
#pour allouer un cadre
fig = plt.figure(figsize=(2 * cols - 1, 2.5 * rows - 1))
for i in range(cols):
    for j in range(rows):
        random_index = np.random.randint(0, len(cropLst))
        #on place chacune des images sur le cadre
        ax = fig.add_subplot(rows, cols, i * rows + j + 1)
        ax.grid('off')
        ax.axis('off')
        img=mpimg.imread(cropLst[random_index])
#         imgplot = plt.imshow(img)
#         plt.show()
#         print (cropLst[random_index])
#         img = cv.imread()
        ax.imshow(img)
        ax.set_title(cropLst[random_index].split(os.path.sep)[1])
plt.show()
