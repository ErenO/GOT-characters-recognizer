# %%
import numpy as np
import cv2 as cv
face_cascade = cv.CascadeClassifier('data/haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('haarcascades/haarcascade_eye.xml')

# %%
nb = 30

# %%
img = cv.imread(imgs[nb])

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
print('Faces found: ', len(faces))
# Out:
# Faces found:  1

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread(imgs[nb])
imgplot = plt.imshow(img)
plt.show()

# %%
def convertToRGB(image):
    return cv.cvtColor(image, cv.COLOR_BGR2RGB)

# %%
for (x,y,w,h) in faces:
#     cv.rectangle(img, (x-20, y-30), (x+w+50, y+h+30), (0, 255, 0), 2)
    crop_img = img[y-30:y+h+30, x-20:x+w+50]

# %%
# crop_img = img[y-30:y+h, x:x+w]

# %%
plt.imshow(crop_img)

# %%
# for (x,y,w,h) in faces:
#     cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#     roi_gray = gray[y:y+h, x:x+w]
#     roi_color = img[y:y+h, x:x+w]
#     eyes = eye_cascade.detectMultiScale(roi_gray)
#     for (ex,ey,ew,eh) in eyes:
#         cv.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

# %%
cv.imshow('img',img)

# %%
import glob as glob

# %%
imgs = []

# %%
for file in glob('../../perso_project/downloads/*/*.jpg'):
    imgs.append(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-4c0049d1cb4d> in <module>
# ----> 1 for file in glob('../../perso_project/downloads/*/*.jpg'):
#       2     imgs.append(file)
#
# TypeError: 'module' object is not callable

# %%
import os

# %%
path = '../../perso_project/downloads/'
for dir_name in os.listdir(path):
    for file in os.listdir(path + dir_name):
        imgs.append("{}{}/{}".format(path, dir_name, file))

# %%
print (len(imgs))
# Out:
# 9924

# %%
imgs[:5]
# Out:
# ['../../perso_project/downloads/Yara Greyjoy games of thrones/Yara Greyjoy 49. s-l300.jpg',
#  '../../perso_project/downloads/Yara Greyjoy games of thrones/Yara Greyjoy 20. 1461830915-tv-game-of-thrones-s06e02-still-05.jpg',
#  '../../perso_project/downloads/Yara Greyjoy games of thrones/Yara Greyjoy 96. tumblr_mjzdxxfrwa1qg0lheo2_250.gif',
#  '../../perso_project/downloads/Yara Greyjoy games of thrones/Yara Greyjoy 19. 5b91e0ef38359aca6e249d94990177af.jpg',
#  '../../perso_project/downloads/Yara Greyjoy games of thrones/Yara Greyjoy 29. ca01cf23d8a91c5115abd72f352bfb41.png']
